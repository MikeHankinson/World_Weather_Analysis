# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Import the datetime module from the datetime library.
from datetime import datetime

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# 6.4.1 Import linear regression from the SciPy stats module.
from scipy.stats import linregress

#import the datetime module from the datetime library.
from datetime import datetime


# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Deliverable 1, Step 3:
# Create a set of random latitude and longitude combinations.
# -------------------------------------------------------------

lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list. 
coordinates = list(lat_lngs)

# %%
# Deliverable 1, Step 4:
# Use the citipy module to determine city based on latitude and longitude.
# -------------------------------------------------------------

from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
cities
# Out:
# ['hobart',
#  'attawapiskat',
#  'saint-philippe',
#  'thompson',
#  'gorin',
#  'taolanaro',
#  'new norfolk',
#  'bredasdorp',
#  'biak',
#  'hasaki',
#  'kirakira',
#  'rikitea',
#  'ponta do sol',
#  'jamestown',
#  'qinhuangdao',
#  'albany',
#  'hermanus',
#  'avarua',
#  'east london',
#  'tiksi',
#  'porto novo',
#  'punta arenas',
#  'ancud',
#  'sampit',
#  'ushuaia',
#  'ahipara',
#  'nguiu',
#  'kurilsk',
#  'severo-kurilsk',
#  'san cristobal',
#  'zhangye',
#  'kapaa',
#  'rabo de peixe',
#  'caravelas',
#  'salalah',
#  'katsuura',
#  'nanortalik',
#  'kyzyl-suu',
#  'takoradi',
#  'rundu',
#  'am timan',
#  'hilo',
#  'norman wells',
#  'illoqqortoormiut',
#  'zelenogorskiy',
#  'cape town',
#  'longlac',
#  'novikovo',
#  'puerto ayora',
#  'aranos',
#  'besuki',
#  'rincon',
#  'mandalgovi',
#  'linping',
#  'port alfred',
#  'maceio',
#  'bermeo',
#  'souillac',
#  'mataura',
#  'vanimo',
#  'novyy urengoy',
#  'henties bay',
#  'meulaboh',
#  'ratnagiri',
#  'madaoua',
#  'belushya guba',
#  'kupang',
#  'barentsburg',
#  'katangli',
#  'saint-malo',
#  'samana',
#  'college',
#  'nouadhibou',
#  'carlisle',
#  'qui nhon',
#  'hithadhoo',
#  'sentyabrskiy',
#  'bluff',
#  'bolungarvik',
#  'olafsvik',
#  'saldanha',
#  'taoudenni',
#  'itarema',
#  'ponta pora',
#  'san vicente',
#  'pisco',
#  'bethel',
#  'baruun-urt',
#  'qaanaaq',
#  'cherskiy',
#  'shanhetun',
#  'villeta',
#  'yangambi',
#  'abu dhabi',
#  'behbahan',
#  'fare',
#  'mahanje',
#  'cabedelo',
#  'tasiilaq',
#  'kongolo',
#  'naryan-mar',
#  'evensk',
#  'ascension',
#  'viedma',
#  'esso',
#  'victoria',
#  'tuktoyaktuk',
#  'port lincoln',
#  'saskylakh',
#  'saint-pierre',
#  'rocha',
#  'tura',
#  'chokurdakh',
#  'broome',
#  'ribeira grande',
#  'puerto baquerizo moreno',
#  'carberry',
#  'mar del plata',
#  'atuona',
#  'belaya kholunitsa',
#  'samusu',
#  'yellowknife',
#  'general roca',
#  'khatanga',
#  'busselton',
#  'amderma',
#  'provideniya',
#  'muros',
#  'vila velha',
#  'san patricio',
#  'vao',
#  'cidreira',
#  'conakry',
#  'upernavik',
#  'sola',
#  'vaini',
#  'sept-iles',
#  'ilulissat',
#  'aljezur',
#  'arroyos y esteros',
#  'yulara',
#  'gulshat',
#  'bengkulu',
#  'nizhneyansk',
#  'mvomero',
#  'mount gambier',
#  'nenjiang',
#  'constitucion',
#  'nuuk',
#  'pevek',
#  'lata',
#  'makakilo city',
#  'kodiak',
#  'gondanglegi',
#  'kaitangata',
#  'nabire',
#  'gannavaram',
#  'talawdi',
#  'hovd',
#  'williston',
#  'yar-sale',
#  'boyolangu',
#  'barcelos',
#  'palabuhanratu',
#  'guadalupe y calvo',
#  'nikolskoye',
#  'luderitz',
#  'pacific grove',
#  'arraial do cabo',
#  'champerico',
#  'honiara',
#  'carrollton',
#  'nemuro',
#  'sakakah',
#  'iraray',
#  'samarai',
#  'vardo',
#  'yuksekova',
#  'mys shmidta',
#  'torbay',
#  'adrar',
#  'gazimurskiy zavod',
#  'husavik',
#  'batticaloa',
#  'barrow',
#  'gazojak',
#  'prince rupert',
#  'grand river south east',
#  'leningradskiy',
#  'ciudad bolivar',
#  'itupiranga',
#  'saint anthony',
#  'barawe',
#  'boffa',
#  'gamba',
#  'tazmalt',
#  'asfi',
#  'anar darreh',
#  'toora-khem',
#  'petropavlovsk-kamchatskiy',
#  'cabo san lucas',
#  'iqaluit',
#  'port elizabeth',
#  'georgetown',
#  'north bend',
#  'komsomolskiy',
#  'binzhou',
#  'santa lucia',
#  'sonoita',
#  'zuwarah',
#  'chernyshevskiy',
#  'vestmannaeyjar',
#  'saint george',
#  'qinnan',
#  'saleaula',
#  'airai',
#  'quatre cocos',
#  'teodoro sampaio',
#  'huadian',
#  'longyearbyen',
#  'ferkessedougou',
#  'haines junction',
#  'warqla',
#  'faya',
#  'dikson',
#  'lebu',
#  'cayenne',
#  'richards bay',
#  'piacabucu',
#  'koulikoro',
#  'lagoa',
#  'paamiut',
#  'kargala',
#  'narsaq',
#  'esperance',
#  'tokmak',
#  'port moresby',
#  'faanui',
#  'walvis bay',
#  'mahebourg',
#  'kruisfontein',
#  'kavieng',
#  'pangnirtung',
#  'viesca',
#  'acapulco',
#  'blumberg',
#  'nhulunbuy',
#  'mercedes',
#  'palmer',
#  'kunszentmiklos',
#  'tautira',
#  'carnarvon',
#  'kontagora',
#  'smithers',
#  'kuyanovo',
#  'bilibino',
#  'wilmington',
#  'athabasca',
#  'micheweni',
#  'wanning',
#  'doctor pedro p. pena',
#  'san quintin',
#  'fairbanks',
#  'brunico',
#  'mmabatho',
#  'yelizovo',
#  'sao filipe',
#  'puerto madero',
#  'nicoya',
#  'kuandian',
#  'imbituba',
#  'osakarovka',
#  'ghimes-faget',
#  'sunnyside',
#  'arman',
#  'kikwit',
#  'esmeraldas',
#  'bashmakovo',
#  'ormara',
#  'butaritari',
#  'saint-denis',
#  'tilichiki',
#  'kushima',
#  'zhezkazgan',
#  'valdivia',
#  'pechora',
#  'ust-kulom',
#  'aquiraz',
#  'trelew',
#  'yumen',
#  'mangrol',
#  'chagda',
#  'solwezi',
#  'louisbourg',
#  'puerto leguizamo',
#  'namibe',
#  'urucui',
#  'davidson',
#  'empalme',
#  'kamenskoye',
#  'ovsyanka',
#  'methoni',
#  'narrabri',
#  'karasjok',
#  'kahului',
#  'kempsey',
#  'bubaque',
#  'waipawa',
#  'san francisco',
#  'itoman',
#  'tuatapere',
#  'dunedin',
#  'port-gentil',
#  'sterling',
#  'morro bay',
#  'gerash',
#  'russell',
#  'bambous virieux',
#  'sioux lookout',
#  'goba',
#  'lanxi',
#  'waingapu',
#  'mahenge',
#  'asau',
#  'luau',
#  'ojinaga',
#  'ayan',
#  'jawhar',
#  'margherita',
#  'tarnos',
#  'termoli',
#  'point pedro',
#  'gedo',
#  'kutum',
#  'chuy',
#  'codrington',
#  'camapua',
#  'poum',
#  'warri',
#  'new richmond',
#  'charcas',
#  'sitka',
#  'sicula',
#  'nigde',
#  'campoverde',
#  'mikhaylovsk',
#  'wang saphung',
#  'hambantota',
#  'avera',
#  'anadyr',
#  'zambezi',
#  'road town',
#  'ituiutaba',
#  'klaksvik',
#  'bac lieu',
#  'oleksandrivka',
#  'bhadrachalam',
#  'siddharthanagar',
#  'karaul',
#  'glamang',
#  'axim',
#  'dalton',
#  'alofi',
#  'kibala',
#  'bandar penggaram',
#  'santander',
#  'flin flon',
#  'jibuti',
#  'marabba',
#  'powell river',
#  'mus',
#  'svetlyy',
#  'kango',
#  'sao jose da coroa grande',
#  'quelimane',
#  'vaitupu',
#  'karad',
#  'lemesos',
#  'yeppoon',
#  'marcona',
#  'deputatskiy',
#  'morondava',
#  'moree',
#  'ghanzi',
#  'qeshm',
#  'ahuimanu',
#  'dandong',
#  'yaring',
#  'batagay',
#  'ballina',
#  'conceicao da barra',
#  'singaraja',
#  'buseresere',
#  'biltine',
#  'lipin bor',
#  'isangel',
#  'huaraz',
#  'jonkoping',
#  'bafq',
#  'gat',
#  'lewistown',
#  'kudahuvadhoo',
#  'hami',
#  'port blair',
#  'labuhan',
#  'puerto madryn',
#  'tessalit',
#  'sinjar',
#  'bulungu',
#  'surgut',
#  'saint-joseph',
#  'yakeshi',
#  'boa esperanca',
#  'namatanai',
#  'skalistyy',
#  'bonthe',
#  'storm lake',
#  'touros',
#  'maymyo',
#  'rybachiy',
#  'tocache',
#  'rawson',
#  'bassar',
#  'ixtapa',
#  'rudnaya pristan',
#  'santa maria',
#  'castro',
#  'marienburg',
#  'port hardy',
#  'irtyshskiy',
#  'verkhnyaya inta',
#  'nishihara',
#  'atambua',
#  'kavaratti',
#  'selcuk',
#  'dharchula',
#  'eenhana',
#  'paredon',
#  'mehamn',
#  'poyarkovo',
#  'okha',
#  'manaure',
#  'bulgan',
#  'tashara',
#  'jalu',
#  'labrea',
#  'rio grande',
#  'sur',
#  'shimoda',
#  'manta',
#  'berbera',
#  'jabinyanah',
#  'dijkot',
#  'touho',
#  'omsukchan',
#  'geraldton',
#  'te anau',
#  'dingle',
#  'umzimvubu',
#  'pleshanovo',
#  'fort nelson',
#  'harper',
#  'padang',
#  'mananara',
#  'tsienyane',
#  'emmett',
#  'erzin',
#  'teluk intan',
#  'lompoc',
#  'zhuanghe',
#  'comodoro rivadavia',
#  'guinticgan',
#  'arcata',
#  'torquay',
#  'tigil',
#  'aldergrove',
#  'mae ramat',
#  'majene',
#  'registro',
#  'clyde river',
#  'satipo',
#  'muzhi',
#  'labutta',
#  'necochea',
#  'virginia beach',
#  'lorengau',
#  'acandi',
#  'maniitsoq',
#  'la asuncion',
#  'husnicioara',
#  'cedar city',
#  'siocon',
#  'khonuu',
#  'krasnoborsk',
#  'bikaner',
#  'ahumada',
#  'juneau',
#  'lima',
#  'fortuna',
#  'broken hill',
#  'les cayes',
#  'vaitape',
#  'along',
#  'asosa',
#  'tommot',
#  'tumannyy',
#  'luanda',
#  'lerwick',
#  'bundaberg',
#  'lar',
#  'bandar-e lengeh',
#  'pran buri',
#  'rimbey',
#  'vigrestad',
#  'los llanos de aridane',
#  'strezhevoy',
#  'fort walton beach',
#  'kazalinsk',
#  'belaya gora',
#  'nauta',
#  'aktash',
#  'abha',
#  'amos',
#  'baracoa',
#  'bergisch gladbach',
#  'karkaralinsk',
#  'coihaique',
#  'kotka',
#  'george',
#  'lasa',
#  'balimo',
#  'portoferraio',
#  'slave lake',
#  'coquimbo',
#  'chengzihe',
#  'margate',
#  'ciro marina',
#  'ugento',
#  'palanpur',
#  'ialibu',
#  'lhuntshi',
#  'seara',
#  'tezu',
#  'malanje',
#  'launceston',
#  'ponta delgada',
#  'presidencia roque saenz pena',
#  'aberdeen',
#  'buala',
#  'tarudant',
#  'palu',
#  'olinda',
#  'burkhala',
#  'iwaki',
#  'teya',
#  'beringovskiy',
#  'simoes',
#  'mindelo',
#  'turiacu',
#  'chandia',
#  'fuling',
#  'mackay',
#  'maniwaki',
#  'zapotiltic',
#  'puerto escondido',
#  'gijon',
#  'fonte boa',
#  'thinadhoo',
#  'igarka',
#  'vodnyy',
#  'mocambique',
#  'toropets',
#  'dickinson',
#  'yarada',
#  'sinnamary',
#  'briancon',
#  'coaldale',
#  'tazovskiy',
#  'tourlaville',
#  'wesselsbron',
#  'cotui',
#  'jijiga',
#  'abu zabad',
#  'neiafu',
#  'bismarck',
#  'san ramon',
#  'arinos',
#  'santa vitoria do palmar',
#  'vila franca do campo',
#  'zhangjiakou',
#  'issaquah',
#  'novo aripuana',
#  'calnali',
#  'melukote',
#  'murgab',
#  'cockburn town',
#  'balagansk',
#  'jiwani',
#  'hay river',
#  'guilin',
#  'bargal',
#  'alyangula',
#  'nibbar',
#  'mount isa',
#  'adre',
#  'khash',
#  'hofn',
#  'mouzakion',
#  'mondlo',
#  'xacmaz',
#  'madimba',
#  'sarangani',
#  'huilong',
#  'sinop',
#  'garoua boulai',
#  'baculin',
#  'la baule-escoublac',
#  'coahuayana',
#  'denholm',
#  'pipri',
#  'jeremoabo',
#  'grand centre',
#  'nakatsu',
#  'manadhoo',
#  'assiniboia',
#  'baghdad',
#  'tabou',
#  'warrnambool',
#  'manakara',
#  'saint-georges',
#  'shache',
#  'tateyama',
#  'camacha',
#  'laguna',
#  'alexandria',
#  'burnie',
#  'qaqortoq',
#  'kloulklubed',
#  'santa rosa',
#  'grand gaube',
#  'bilma',
#  'meyungs',
#  'tuy hoa',
#  'ostashkov',
#  'zambrow',
#  'marrakesh',
#  'ondjiva',
#  'baykit',
#  'neiba',
#  'olhao',
#  'tripoli',
#  'watertown',
#  'elbasan',
#  'voskresenskoye',
#  'tikrit',
#  'sungaipenuh',
#  'katherine',
#  'derbent',
#  'kostomuksha',
#  'aleksandrov gay',
#  'christchurch',
#  'likasi',
#  'bukavu',
#  'berdigestyakh',
#  'matanzas',
#  'mnogovershinnyy',
#  'flinders',
#  'mafinga',
#  'sibenik',
#  'hobyo',
#  'bonavista',
#  'ambon',
#  'alice springs',
#  'coos bay',
#  'bom jesus',
#  'miles city',
#  'spas-klepiki',
#  'kosh-agach',
#  'pontianak',
#  'katesh',
#  'dawlatabad',
#  'tabas',
#  'stephenville',
#  'mishelevka',
#  'ulladulla',
#  'burns lake',
#  'kanalion',
#  'lomza',
#  'atar',
#  'goderich',
#  'manggar',
#  'arlit',
#  'wahpeton',
#  'nisia floresta',
#  'nampula',
#  'lufilufi',
#  'santa cruz',
#  'morris',
#  'marsaxlokk',
#  'skagastrond',
#  'bolivar',
#  'andenes',
#  'salto',
#  'aklavik',
#  'sayville',
#  'visnes',
#  'kanakapura',
#  'tsirguliina',
#  'abrau-dyurso',
#  'colares',
#  'cocorit',
#  'bonanza',
#  'leh',
#  'kilindoni',
#  'preobrazheniye',
#  'tignere',
#  'kodinsk',
#  'nadym',
#  'poopo',
#  'saravena',
#  'roswell',
#  'bam',
#  'tamandare',
#  'forio',
#  'gilazi',
#  'behshahr',
#  'mayo',
#  'xianshuigu',
#  'keti bandar',
#  'winton',
#  'montbrison',
#  'san felipe',
#  'libertad',
#  'kieta',
#  'cortez',
#  'sorong',
#  'zhigansk',
#  'beyneu',
#  'kinshasa',
#  'verkhoyansk',
#  'sabang',
#  'tsihombe',
#  'puro',
#  'hernani',
#  'utiroa',
#  'kununurra',
#  'novyy urgal',
#  'terney',
#  'huanan',
#  'kulhudhuffushi',
#  'marand',
#  'poya',
#  'kayes',
#  'luneville',
#  'karsava',
#  'manuk mangkaw',
#  'naze',
#  'havelock',
#  'srandakan',
#  'pafos',
#  'tabarqah',
#  'ovalle',
#  'mahajanga',
#  'havoysund',
#  'gazanjyk',
#  'camana',
#  'vilyuysk',
#  'mizpe ramon']

# %%
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 768

# %%
# Deliverable 1, Step 5: Perform API Call with OpenWeatherMap and,
# Deliverable 1, Step 6:Perform an API call with the OpenWeatherMap
# -------------------------------------------------------------


# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# 2. Loop through all the cities in our list.
for i, city in enumerate(cities):

    # 3. Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # 4. Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # 5. Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} : {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # 6. Run an API request for each of the cities.
    try:
        # 7. Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Weather Description": city_description,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
    

    
# **reminder: % is modulus: Divides left hand operand by 
# right hand operand and returns remainder **


# **reminder: += is Add AND: It adds right operand to the 
# left operand and assign the result to left operand
# c += a is c = c + a **

# **Use the enumerate() method as an alternative way to iterate 
# through the list of cities and retrieve both the index, 
# and the city from the list.
# enumerate syntax is for i, item/index in enumerate(list):  **

# **city.replace(" ","+"): concatenates out blank spaces in url. ** 

# **Add a try-except block to the code to prevent the API request 
# from stopping prematurely if the city_weather request isn't a valid 
# response. If the request isn't valid, the code will not find the 
# first item requested, which is the dictionary "coord" with the code
# city_lat = city_weather["coord"]["lat"], and skip the city and 
# continue to run. **
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 : hobart
# Processing Record 2 of Set 1 : attawapiskat
# City not found. Skipping...
# Processing Record 3 of Set 1 : saint-philippe
# Processing Record 4 of Set 1 : thompson
# Processing Record 5 of Set 1 : gorin
# Processing Record 6 of Set 1 : taolanaro
# City not found. Skipping...
# Processing Record 7 of Set 1 : new norfolk
# Processing Record 8 of Set 1 : bredasdorp
# Processing Record 9 of Set 1 : biak
# Processing Record 10 of Set 1 : hasaki
# Processing Record 11 of Set 1 : kirakira
# Processing Record 12 of Set 1 : rikitea
# Processing Record 13 of Set 1 : ponta do sol
# Processing Record 14 of Set 1 : jamestown
# Processing Record 15 of Set 1 : qinhuangdao
# Processing Record 16 of Set 1 : albany
# Processing Record 17 of Set 1 : hermanus
# Processing Record 18 of Set 1 : avarua
# Processing Record 19 of Set 1 : east london
# Processing Record 20 of Set 1 : tiksi
# Processing Record 21 of Set 1 : porto novo
# Processing Record 22 of Set 1 : punta arenas
# Processing Record 23 of Set 1 : ancud
# Processing Record 24 of Set 1 : sampit
# Processing Record 25 of Set 1 : ushuaia
# Processing Record 26 of Set 1 : ahipara
# Processing Record 27 of Set 1 : nguiu
# City not found. Skipping...
# Processing Record 28 of Set 1 : kurilsk
# Processing Record 29 of Set 1 : severo-kurilsk
# Processing Record 30 of Set 1 : san cristobal
# Processing Record 31 of Set 1 : zhangye
# Processing Record 32 of Set 1 : kapaa
# Processing Record 33 of Set 1 : rabo de peixe
# Processing Record 34 of Set 1 : caravelas
# Processing Record 35 of Set 1 : salalah
# Processing Record 36 of Set 1 : katsuura
# Processing Record 37 of Set 1 : nanortalik
# Processing Record 38 of Set 1 : kyzyl-suu
# Processing Record 39 of Set 1 : takoradi
# Processing Record 40 of Set 1 : rundu
# Processing Record 41 of Set 1 : am timan
# Processing Record 42 of Set 1 : hilo
# Processing Record 43 of Set 1 : norman wells
# Processing Record 44 of Set 1 : illoqqortoormiut
# City not found. Skipping...
# Processing Record 45 of Set 1 : zelenogorskiy
# Processing Record 46 of Set 1 : cape town
# Processing Record 47 of Set 1 : longlac
# City not found. Skipping...
# Processing Record 48 of Set 1 : novikovo
# Processing Record 49 of Set 1 : puerto ayora
# Processing Record 50 of Set 1 : aranos
# Processing Record 1 of Set 2 : besuki
# Processing Record 2 of Set 2 : rincon
# Processing Record 3 of Set 2 : mandalgovi
# Processing Record 4 of Set 2 : linping
# Processing Record 5 of Set 2 : port alfred
# Processing Record 6 of Set 2 : maceio
# Processing Record 7 of Set 2 : bermeo
# Processing Record 8 of Set 2 : souillac
# Processing Record 9 of Set 2 : mataura
# Processing Record 10 of Set 2 : vanimo
# Processing Record 11 of Set 2 : novyy urengoy
# Processing Record 12 of Set 2 : henties bay
# Processing Record 13 of Set 2 : meulaboh
# Processing Record 14 of Set 2 : ratnagiri
# Processing Record 15 of Set 2 : madaoua
# Processing Record 16 of Set 2 : belushya guba
# City not found. Skipping...
# Processing Record 17 of Set 2 : kupang
# Processing Record 18 of Set 2 : barentsburg
# City not found. Skipping...
# Processing Record 19 of Set 2 : katangli
# Processing Record 20 of Set 2 : saint-malo
# Processing Record 21 of Set 2 : samana
# Processing Record 22 of Set 2 : college
# Processing Record 23 of Set 2 : nouadhibou
# Processing Record 24 of Set 2 : carlisle
# Processing Record 25 of Set 2 : qui nhon
# Processing Record 26 of Set 2 : hithadhoo
# Processing Record 27 of Set 2 : sentyabrskiy
# City not found. Skipping...
# Processing Record 28 of Set 2 : bluff
# Processing Record 29 of Set 2 : bolungarvik
# City not found. Skipping...
# Processing Record 30 of Set 2 : olafsvik
# Processing Record 31 of Set 2 : saldanha
# Processing Record 32 of Set 2 : taoudenni
# Processing Record 33 of Set 2 : itarema
# Processing Record 34 of Set 2 : ponta pora
# Processing Record 35 of Set 2 : san vicente
# Processing Record 36 of Set 2 : pisco
# Processing Record 37 of Set 2 : bethel
# Processing Record 38 of Set 2 : baruun-urt
# Processing Record 39 of Set 2 : qaanaaq
# Processing Record 40 of Set 2 : cherskiy
# Processing Record 41 of Set 2 : shanhetun
# Processing Record 42 of Set 2 : villeta
# Processing Record 43 of Set 2 : yangambi
# Processing Record 44 of Set 2 : abu dhabi
# Processing Record 45 of Set 2 : behbahan
# Processing Record 46 of Set 2 : fare
# Processing Record 47 of Set 2 : mahanje
# Processing Record 48 of Set 2 : cabedelo
# Processing Record 49 of Set 2 : tasiilaq
# Processing Record 50 of Set 2 : kongolo
# Processing Record 1 of Set 3 : naryan-mar
# Processing Record 2 of Set 3 : evensk
# Processing Record 3 of Set 3 : ascension
# Processing Record 4 of Set 3 : viedma
# Processing Record 5 of Set 3 : esso
# Processing Record 6 of Set 3 : victoria
# Processing Record 7 of Set 3 : tuktoyaktuk
# Processing Record 8 of Set 3 : port lincoln
# Processing Record 9 of Set 3 : saskylakh
# Processing Record 10 of Set 3 : saint-pierre
# Processing Record 11 of Set 3 : rocha
# Processing Record 12 of Set 3 : tura
# Processing Record 13 of Set 3 : chokurdakh
# Processing Record 14 of Set 3 : broome
# Processing Record 15 of Set 3 : ribeira grande
# Processing Record 16 of Set 3 : puerto baquerizo moreno
# Processing Record 17 of Set 3 : carberry
# Processing Record 18 of Set 3 : mar del plata
# Processing Record 19 of Set 3 : atuona
# Processing Record 20 of Set 3 : belaya kholunitsa
# Processing Record 21 of Set 3 : samusu
# City not found. Skipping...
# Processing Record 22 of Set 3 : yellowknife
# Processing Record 23 of Set 3 : general roca
# Processing Record 24 of Set 3 : khatanga
# Processing Record 25 of Set 3 : busselton
# Processing Record 26 of Set 3 : amderma
# City not found. Skipping...
# Processing Record 27 of Set 3 : provideniya
# Processing Record 28 of Set 3 : muros
# Processing Record 29 of Set 3 : vila velha
# Processing Record 30 of Set 3 : san patricio
# Processing Record 31 of Set 3 : vao
# Processing Record 32 of Set 3 : cidreira
# Processing Record 33 of Set 3 : conakry
# Processing Record 34 of Set 3 : upernavik
# Processing Record 35 of Set 3 : sola
# Processing Record 36 of Set 3 : vaini
# Processing Record 37 of Set 3 : sept-iles
# Processing Record 38 of Set 3 : ilulissat
# Processing Record 39 of Set 3 : aljezur
# Processing Record 40 of Set 3 : arroyos y esteros
# Processing Record 41 of Set 3 : yulara
# Processing Record 42 of Set 3 : gulshat
# City not found. Skipping...
# Processing Record 43 of Set 3 : bengkulu
# Processing Record 44 of Set 3 : nizhneyansk
# City not found. Skipping...
# Processing Record 45 of Set 3 : mvomero
# Processing Record 46 of Set 3 : mount gambier
# Processing Record 47 of Set 3 : nenjiang
# Processing Record 48 of Set 3 : constitucion
# Processing Record 49 of Set 3 : nuuk
# Processing Record 50 of Set 3 : pevek
# Processing Record 1 of Set 4 : lata
# Processing Record 2 of Set 4 : makakilo city
# Processing Record 3 of Set 4 : kodiak
# Processing Record 4 of Set 4 : gondanglegi
# Processing Record 5 of Set 4 : kaitangata
# Processing Record 6 of Set 4 : nabire
# Processing Record 7 of Set 4 : gannavaram
# Processing Record 8 of Set 4 : talawdi
# City not found. Skipping...
# Processing Record 9 of Set 4 : hovd
# Processing Record 10 of Set 4 : williston
# Processing Record 11 of Set 4 : yar-sale
# Processing Record 12 of Set 4 : boyolangu
# Processing Record 13 of Set 4 : barcelos
# Processing Record 14 of Set 4 : palabuhanratu
# City not found. Skipping...
# Processing Record 15 of Set 4 : guadalupe y calvo
# Processing Record 16 of Set 4 : nikolskoye
# Processing Record 17 of Set 4 : luderitz
# Processing Record 18 of Set 4 : pacific grove
# Processing Record 19 of Set 4 : arraial do cabo
# Processing Record 20 of Set 4 : champerico
# Processing Record 21 of Set 4 : honiara
# Processing Record 22 of Set 4 : carrollton
# Processing Record 23 of Set 4 : nemuro
# Processing Record 24 of Set 4 : sakakah
# Processing Record 25 of Set 4 : iraray
# Processing Record 26 of Set 4 : samarai
# Processing Record 27 of Set 4 : vardo
# Processing Record 28 of Set 4 : yuksekova
# Processing Record 29 of Set 4 : mys shmidta
# City not found. Skipping...
# Processing Record 30 of Set 4 : torbay
# Processing Record 31 of Set 4 : adrar
# Processing Record 32 of Set 4 : gazimurskiy zavod
# Processing Record 33 of Set 4 : husavik
# Processing Record 34 of Set 4 : batticaloa
# Processing Record 35 of Set 4 : barrow
# Processing Record 36 of Set 4 : gazojak
# Processing Record 37 of Set 4 : prince rupert
# Processing Record 38 of Set 4 : grand river south east
# City not found. Skipping...
# Processing Record 39 of Set 4 : leningradskiy
# Processing Record 40 of Set 4 : ciudad bolivar
# Processing Record 41 of Set 4 : itupiranga
# Processing Record 42 of Set 4 : saint anthony
# Processing Record 43 of Set 4 : barawe
# City not found. Skipping...
# Processing Record 44 of Set 4 : boffa
# Processing Record 45 of Set 4 : gamba
# Processing Record 46 of Set 4 : tazmalt
# Processing Record 47 of Set 4 : asfi
# Processing Record 48 of Set 4 : anar darreh
# City not found. Skipping...
# Processing Record 49 of Set 4 : toora-khem
# Processing Record 50 of Set 4 : petropavlovsk-kamchatskiy
# Processing Record 1 of Set 5 : cabo san lucas
# Processing Record 2 of Set 5 : iqaluit
# Processing Record 3 of Set 5 : port elizabeth
# Processing Record 4 of Set 5 : georgetown
# Processing Record 5 of Set 5 : north bend
# Processing Record 6 of Set 5 : komsomolskiy
# Processing Record 7 of Set 5 : binzhou
# Processing Record 8 of Set 5 : santa lucia
# Processing Record 9 of Set 5 : sonoita
# Processing Record 10 of Set 5 : zuwarah
# Processing Record 11 of Set 5 : chernyshevskiy
# Processing Record 12 of Set 5 : vestmannaeyjar
# Processing Record 13 of Set 5 : saint george
# Processing Record 14 of Set 5 : qinnan
# Processing Record 15 of Set 5 : saleaula
# City not found. Skipping...
# Processing Record 16 of Set 5 : airai
# Processing Record 17 of Set 5 : quatre cocos
# Processing Record 18 of Set 5 : teodoro sampaio
# Processing Record 19 of Set 5 : huadian
# Processing Record 20 of Set 5 : longyearbyen
# Processing Record 21 of Set 5 : ferkessedougou
# Processing Record 22 of Set 5 : haines junction
# Processing Record 23 of Set 5 : warqla
# City not found. Skipping...
# Processing Record 24 of Set 5 : faya
# Processing Record 25 of Set 5 : dikson
# Processing Record 26 of Set 5 : lebu
# Processing Record 27 of Set 5 : cayenne
# Processing Record 28 of Set 5 : richards bay
# Processing Record 29 of Set 5 : piacabucu
# Processing Record 30 of Set 5 : koulikoro
# Processing Record 31 of Set 5 : lagoa
# Processing Record 32 of Set 5 : paamiut
# Processing Record 33 of Set 5 : kargala
# Processing Record 34 of Set 5 : narsaq
# Processing Record 35 of Set 5 : esperance
# Processing Record 36 of Set 5 : tokmak
# Processing Record 37 of Set 5 : port moresby
# Processing Record 38 of Set 5 : faanui
# Processing Record 39 of Set 5 : walvis bay
# Processing Record 40 of Set 5 : mahebourg
# Processing Record 41 of Set 5 : kruisfontein
# Processing Record 42 of Set 5 : kavieng
# Processing Record 43 of Set 5 : pangnirtung
# Processing Record 44 of Set 5 : viesca
# Processing Record 45 of Set 5 : acapulco
# Processing Record 46 of Set 5 : blumberg
# Processing Record 47 of Set 5 : nhulunbuy
# Processing Record 48 of Set 5 : mercedes
# Processing Record 49 of Set 5 : palmer
# Processing Record 50 of Set 5 : kunszentmiklos
# Processing Record 1 of Set 6 : tautira
# Processing Record 2 of Set 6 : carnarvon
# Processing Record 3 of Set 6 : kontagora
# Processing Record 4 of Set 6 : smithers
# Processing Record 5 of Set 6 : kuyanovo
# Processing Record 6 of Set 6 : bilibino
# Processing Record 7 of Set 6 : wilmington
# Processing Record 8 of Set 6 : athabasca
# Processing Record 9 of Set 6 : micheweni
# Processing Record 10 of Set 6 : wanning
# Processing Record 11 of Set 6 : doctor pedro p. pena
# City not found. Skipping...
# Processing Record 12 of Set 6 : san quintin
# Processing Record 13 of Set 6 : fairbanks
# Processing Record 14 of Set 6 : brunico
# Processing Record 15 of Set 6 : mmabatho
# Processing Record 16 of Set 6 : yelizovo
# Processing Record 17 of Set 6 : sao filipe
# Processing Record 18 of Set 6 : puerto madero
# Processing Record 19 of Set 6 : nicoya
# Processing Record 20 of Set 6 : kuandian
# Processing Record 21 of Set 6 : imbituba
# Processing Record 22 of Set 6 : osakarovka
# Processing Record 23 of Set 6 : ghimes-faget
# Processing Record 24 of Set 6 : sunnyside
# Processing Record 25 of Set 6 : arman
# Processing Record 26 of Set 6 : kikwit
# Processing Record 27 of Set 6 : esmeraldas
# Processing Record 28 of Set 6 : bashmakovo
# Processing Record 29 of Set 6 : ormara
# Processing Record 30 of Set 6 : butaritari
# Processing Record 31 of Set 6 : saint-denis
# Processing Record 32 of Set 6 : tilichiki
# Processing Record 33 of Set 6 : kushima
# Processing Record 34 of Set 6 : zhezkazgan
# Processing Record 35 of Set 6 : valdivia
# Processing Record 36 of Set 6 : pechora
# Processing Record 37 of Set 6 : ust-kulom
# Processing Record 38 of Set 6 : aquiraz
# Processing Record 39 of Set 6 : trelew
# Processing Record 40 of Set 6 : yumen
# Processing Record 41 of Set 6 : mangrol
# Processing Record 42 of Set 6 : chagda
# City not found. Skipping...
# Processing Record 43 of Set 6 : solwezi
# Processing Record 44 of Set 6 : louisbourg
# City not found. Skipping...
# Processing Record 45 of Set 6 : puerto leguizamo
# Processing Record 46 of Set 6 : namibe
# Processing Record 47 of Set 6 : urucui
# Processing Record 48 of Set 6 : davidson
# Processing Record 49 of Set 6 : empalme
# Processing Record 50 of Set 6 : kamenskoye
# City not found. Skipping...
# Processing Record 1 of Set 7 : ovsyanka
# Processing Record 2 of Set 7 : methoni
# Processing Record 3 of Set 7 : narrabri
# Processing Record 4 of Set 7 : karasjok
# Processing Record 5 of Set 7 : kahului
# Processing Record 6 of Set 7 : kempsey
# Processing Record 7 of Set 7 : bubaque
# Processing Record 8 of Set 7 : waipawa
# Processing Record 9 of Set 7 : san francisco
# Processing Record 10 of Set 7 : itoman
# Processing Record 11 of Set 7 : tuatapere
# Processing Record 12 of Set 7 : dunedin
# Processing Record 13 of Set 7 : port-gentil
# Processing Record 14 of Set 7 : sterling
# Processing Record 15 of Set 7 : morro bay
# Processing Record 16 of Set 7 : gerash
# Processing Record 17 of Set 7 : russell
# Processing Record 18 of Set 7 : bambous virieux
# Processing Record 19 of Set 7 : sioux lookout
# Processing Record 20 of Set 7 : goba
# Processing Record 21 of Set 7 : lanxi
# Processing Record 22 of Set 7 : waingapu
# Processing Record 23 of Set 7 : mahenge
# Processing Record 24 of Set 7 : asau
# Processing Record 25 of Set 7 : luau
# Processing Record 26 of Set 7 : ojinaga
# Processing Record 27 of Set 7 : ayan
# Processing Record 28 of Set 7 : jawhar
# Processing Record 29 of Set 7 : margherita
# Processing Record 30 of Set 7 : tarnos
# Processing Record 31 of Set 7 : termoli
# Processing Record 32 of Set 7 : point pedro
# Processing Record 33 of Set 7 : gedo
# Processing Record 34 of Set 7 : kutum
# Processing Record 35 of Set 7 : chuy
# Processing Record 36 of Set 7 : codrington
# Processing Record 37 of Set 7 : camapua
# Processing Record 38 of Set 7 : poum
# Processing Record 39 of Set 7 : warri
# Processing Record 40 of Set 7 : new richmond
# Processing Record 41 of Set 7 : charcas
# Processing Record 42 of Set 7 : sitka
# Processing Record 43 of Set 7 : sicula
# Processing Record 44 of Set 7 : nigde
# Processing Record 45 of Set 7 : campoverde
# Processing Record 46 of Set 7 : mikhaylovsk
# Processing Record 47 of Set 7 : wang saphung
# Processing Record 48 of Set 7 : hambantota
# Processing Record 49 of Set 7 : avera
# Processing Record 50 of Set 7 : anadyr
# Processing Record 1 of Set 8 : zambezi
# Processing Record 2 of Set 8 : road town
# Processing Record 3 of Set 8 : ituiutaba
# Processing Record 4 of Set 8 : klaksvik
# Processing Record 5 of Set 8 : bac lieu
# Processing Record 6 of Set 8 : oleksandrivka
# Processing Record 7 of Set 8 : bhadrachalam
# Processing Record 8 of Set 8 : siddharthanagar
# Processing Record 9 of Set 8 : karaul
# City not found. Skipping...
# Processing Record 10 of Set 8 : glamang
# Processing Record 11 of Set 8 : axim
# Processing Record 12 of Set 8 : dalton
# Processing Record 13 of Set 8 : alofi
# Processing Record 14 of Set 8 : kibala
# Processing Record 15 of Set 8 : bandar penggaram
# City not found. Skipping...
# Processing Record 16 of Set 8 : santander
# Processing Record 17 of Set 8 : flin flon
# Processing Record 18 of Set 8 : jibuti
# Processing Record 19 of Set 8 : marabba
# Processing Record 20 of Set 8 : powell river
# Processing Record 21 of Set 8 : mus
# Processing Record 22 of Set 8 : svetlyy
# Processing Record 23 of Set 8 : kango
# Processing Record 24 of Set 8 : sao jose da coroa grande
# Processing Record 25 of Set 8 : quelimane
# Processing Record 26 of Set 8 : vaitupu
# City not found. Skipping...
# Processing Record 27 of Set 8 : karad
# Processing Record 28 of Set 8 : lemesos
# City not found. Skipping...
# Processing Record 29 of Set 8 : yeppoon
# Processing Record 30 of Set 8 : marcona
# City not found. Skipping...
# Processing Record 31 of Set 8 : deputatskiy
# Processing Record 32 of Set 8 : morondava
# Processing Record 33 of Set 8 : moree
# Processing Record 34 of Set 8 : ghanzi
# Processing Record 35 of Set 8 : qeshm
# Processing Record 36 of Set 8 : ahuimanu
# Processing Record 37 of Set 8 : dandong
# Processing Record 38 of Set 8 : yaring
# Processing Record 39 of Set 8 : batagay
# Processing Record 40 of Set 8 : ballina
# Processing Record 41 of Set 8 : conceicao da barra
# Processing Record 42 of Set 8 : singaraja
# Processing Record 43 of Set 8 : buseresere
# Processing Record 44 of Set 8 : biltine
# Processing Record 45 of Set 8 : lipin bor
# Processing Record 46 of Set 8 : isangel
# Processing Record 47 of Set 8 : huaraz
# Processing Record 48 of Set 8 : jonkoping
# Processing Record 49 of Set 8 : bafq
# Processing Record 50 of Set 8 : gat
# Processing Record 1 of Set 9 : lewistown
# Processing Record 2 of Set 9 : kudahuvadhoo
# Processing Record 3 of Set 9 : hami
# Processing Record 4 of Set 9 : port blair
# Processing Record 5 of Set 9 : labuhan
# Processing Record 6 of Set 9 : puerto madryn
# Processing Record 7 of Set 9 : tessalit
# Processing Record 8 of Set 9 : sinjar
# Processing Record 9 of Set 9 : bulungu
# Processing Record 10 of Set 9 : surgut
# Processing Record 11 of Set 9 : saint-joseph
# Processing Record 12 of Set 9 : yakeshi
# Processing Record 13 of Set 9 : boa esperanca
# Processing Record 14 of Set 9 : namatanai
# Processing Record 15 of Set 9 : skalistyy
# City not found. Skipping...
# Processing Record 16 of Set 9 : bonthe
# Processing Record 17 of Set 9 : storm lake
# Processing Record 18 of Set 9 : touros
# Processing Record 19 of Set 9 : maymyo
# Processing Record 20 of Set 9 : rybachiy
# Processing Record 21 of Set 9 : tocache
# Processing Record 22 of Set 9 : rawson
# Processing Record 23 of Set 9 : bassar
# Processing Record 24 of Set 9 : ixtapa
# Processing Record 25 of Set 9 : rudnaya pristan
# Processing Record 26 of Set 9 : santa maria
# Processing Record 27 of Set 9 : castro
# Processing Record 28 of Set 9 : marienburg
# Processing Record 29 of Set 9 : port hardy
# Processing Record 30 of Set 9 : irtyshskiy
# Processing Record 31 of Set 9 : verkhnyaya inta
# Processing Record 32 of Set 9 : nishihara
# Processing Record 33 of Set 9 : atambua
# Processing Record 34 of Set 9 : kavaratti
# Processing Record 35 of Set 9 : selcuk
# Processing Record 36 of Set 9 : dharchula
# Processing Record 37 of Set 9 : eenhana
# Processing Record 38 of Set 9 : paredon
# Processing Record 39 of Set 9 : mehamn
# City not found. Skipping...
# Processing Record 40 of Set 9 : poyarkovo
# Processing Record 41 of Set 9 : okha
# Processing Record 42 of Set 9 : manaure
# Processing Record 43 of Set 9 : bulgan
# Processing Record 44 of Set 9 : tashara
# Processing Record 45 of Set 9 : jalu
# Processing Record 46 of Set 9 : labrea
# Processing Record 47 of Set 9 : rio grande
# Processing Record 48 of Set 9 : sur
# Processing Record 49 of Set 9 : shimoda
# Processing Record 50 of Set 9 : manta
# Processing Record 1 of Set 10 : berbera
# Processing Record 2 of Set 10 : jabinyanah
# Processing Record 3 of Set 10 : dijkot
# Processing Record 4 of Set 10 : touho
# Processing Record 5 of Set 10 : omsukchan
# Processing Record 6 of Set 10 : geraldton
# Processing Record 7 of Set 10 : te anau
# Processing Record 8 of Set 10 : dingle
# Processing Record 9 of Set 10 : umzimvubu
# City not found. Skipping...
# Processing Record 10 of Set 10 : pleshanovo
# Processing Record 11 of Set 10 : fort nelson
# Processing Record 12 of Set 10 : harper
# Processing Record 13 of Set 10 : padang
# Processing Record 14 of Set 10 : mananara
# Processing Record 15 of Set 10 : tsienyane
# City not found. Skipping...
# Processing Record 16 of Set 10 : emmett
# Processing Record 17 of Set 10 : erzin
# Processing Record 18 of Set 10 : teluk intan
# Processing Record 19 of Set 10 : lompoc
# Processing Record 20 of Set 10 : zhuanghe
# Processing Record 21 of Set 10 : comodoro rivadavia
# Processing Record 22 of Set 10 : guinticgan
# Processing Record 23 of Set 10 : arcata
# Processing Record 24 of Set 10 : torquay
# Processing Record 25 of Set 10 : tigil
# Processing Record 26 of Set 10 : aldergrove
# Processing Record 27 of Set 10 : mae ramat
# Processing Record 28 of Set 10 : majene
# Processing Record 29 of Set 10 : registro
# Processing Record 30 of Set 10 : clyde river
# Processing Record 31 of Set 10 : satipo
# Processing Record 32 of Set 10 : muzhi
# Processing Record 33 of Set 10 : labutta
# City not found. Skipping...
# Processing Record 34 of Set 10 : necochea
# Processing Record 35 of Set 10 : virginia beach
# Processing Record 36 of Set 10 : lorengau
# Processing Record 37 of Set 10 : acandi
# Processing Record 38 of Set 10 : maniitsoq
# Processing Record 39 of Set 10 : la asuncion
# Processing Record 40 of Set 10 : husnicioara
# Processing Record 41 of Set 10 : cedar city
# Processing Record 42 of Set 10 : siocon
# Processing Record 43 of Set 10 : khonuu
# City not found. Skipping...
# Processing Record 44 of Set 10 : krasnoborsk
# Processing Record 45 of Set 10 : bikaner
# Processing Record 46 of Set 10 : ahumada
# City not found. Skipping...
# Processing Record 47 of Set 10 : juneau
# Processing Record 48 of Set 10 : lima
# Processing Record 49 of Set 10 : fortuna
# Processing Record 50 of Set 10 : broken hill
# Processing Record 1 of Set 11 : les cayes
# Processing Record 2 of Set 11 : vaitape
# Processing Record 3 of Set 11 : along
# Processing Record 4 of Set 11 : asosa
# Processing Record 5 of Set 11 : tommot
# Processing Record 6 of Set 11 : tumannyy
# City not found. Skipping...
# Processing Record 7 of Set 11 : luanda
# Processing Record 8 of Set 11 : lerwick
# Processing Record 9 of Set 11 : bundaberg
# Processing Record 10 of Set 11 : lar
# Processing Record 11 of Set 11 : bandar-e lengeh
# Processing Record 12 of Set 11 : pran buri
# Processing Record 13 of Set 11 : rimbey
# Processing Record 14 of Set 11 : vigrestad
# Processing Record 15 of Set 11 : los llanos de aridane
# Processing Record 16 of Set 11 : strezhevoy
# Processing Record 17 of Set 11 : fort walton beach
# Processing Record 18 of Set 11 : kazalinsk
# City not found. Skipping...
# Processing Record 19 of Set 11 : belaya gora
# Processing Record 20 of Set 11 : nauta
# Processing Record 21 of Set 11 : aktash
# Processing Record 22 of Set 11 : abha
# Processing Record 23 of Set 11 : amos
# Processing Record 24 of Set 11 : baracoa
# Processing Record 25 of Set 11 : bergisch gladbach
# Processing Record 26 of Set 11 : karkaralinsk
# City not found. Skipping...
# Processing Record 27 of Set 11 : coihaique
# Processing Record 28 of Set 11 : kotka
# Processing Record 29 of Set 11 : george
# Processing Record 30 of Set 11 : lasa
# Processing Record 31 of Set 11 : balimo
# City not found. Skipping...
# Processing Record 32 of Set 11 : portoferraio
# Processing Record 33 of Set 11 : slave lake
# Processing Record 34 of Set 11 : coquimbo
# Processing Record 35 of Set 11 : chengzihe
# Processing Record 36 of Set 11 : margate
# Processing Record 37 of Set 11 : ciro marina
# Processing Record 38 of Set 11 : ugento
# Processing Record 39 of Set 11 : palanpur
# Processing Record 40 of Set 11 : ialibu
# Processing Record 41 of Set 11 : lhuntshi
# City not found. Skipping...
# Processing Record 42 of Set 11 : seara
# Processing Record 43 of Set 11 : tezu
# Processing Record 44 of Set 11 : malanje
# Processing Record 45 of Set 11 : launceston
# Processing Record 46 of Set 11 : ponta delgada
# Processing Record 47 of Set 11 : presidencia roque saenz pena
# Processing Record 48 of Set 11 : aberdeen
# Processing Record 49 of Set 11 : buala
# Processing Record 50 of Set 11 : tarudant
# City not found. Skipping...
# Processing Record 1 of Set 12 : palu
# Processing Record 2 of Set 12 : olinda
# Processing Record 3 of Set 12 : burkhala
# City not found. Skipping...
# Processing Record 4 of Set 12 : iwaki
# Processing Record 5 of Set 12 : teya
# Processing Record 6 of Set 12 : beringovskiy
# Processing Record 7 of Set 12 : simoes
# Processing Record 8 of Set 12 : mindelo
# Processing Record 9 of Set 12 : turiacu
# Processing Record 10 of Set 12 : chandia
# Processing Record 11 of Set 12 : fuling
# Processing Record 12 of Set 12 : mackay
# Processing Record 13 of Set 12 : maniwaki
# Processing Record 14 of Set 12 : zapotiltic
# Processing Record 15 of Set 12 : puerto escondido
# Processing Record 16 of Set 12 : gijon
# Processing Record 17 of Set 12 : fonte boa
# Processing Record 18 of Set 12 : thinadhoo
# Processing Record 19 of Set 12 : igarka
# Processing Record 20 of Set 12 : vodnyy
# Processing Record 21 of Set 12 : mocambique
# City not found. Skipping...
# Processing Record 22 of Set 12 : toropets
# Processing Record 23 of Set 12 : dickinson
# Processing Record 24 of Set 12 : yarada
# Processing Record 25 of Set 12 : sinnamary
# Processing Record 26 of Set 12 : briancon
# Processing Record 27 of Set 12 : coaldale
# Processing Record 28 of Set 12 : tazovskiy
# Processing Record 29 of Set 12 : tourlaville
# Processing Record 30 of Set 12 : wesselsbron
# Processing Record 31 of Set 12 : cotui
# Processing Record 32 of Set 12 : jijiga
# Processing Record 33 of Set 12 : abu zabad
# Processing Record 34 of Set 12 : neiafu
# Processing Record 35 of Set 12 : bismarck
# Processing Record 36 of Set 12 : san ramon
# Processing Record 37 of Set 12 : arinos
# Processing Record 38 of Set 12 : santa vitoria do palmar
# Processing Record 39 of Set 12 : vila franca do campo
# Processing Record 40 of Set 12 : zhangjiakou
# Processing Record 41 of Set 12 : issaquah
# Processing Record 42 of Set 12 : novo aripuana
# Processing Record 43 of Set 12 : calnali
# Processing Record 44 of Set 12 : melukote
# Processing Record 45 of Set 12 : murgab
# Processing Record 46 of Set 12 : cockburn town
# Processing Record 47 of Set 12 : balagansk
# Processing Record 48 of Set 12 : jiwani
# Processing Record 49 of Set 12 : hay river
# Processing Record 50 of Set 12 : guilin
# Processing Record 1 of Set 13 : bargal
# City not found. Skipping...
# Processing Record 2 of Set 13 : alyangula
# Processing Record 3 of Set 13 : nibbar
# Processing Record 4 of Set 13 : mount isa
# Processing Record 5 of Set 13 : adre
# Processing Record 6 of Set 13 : khash
# Processing Record 7 of Set 13 : hofn
# Processing Record 8 of Set 13 : mouzakion
# City not found. Skipping...
# Processing Record 9 of Set 13 : mondlo
# Processing Record 10 of Set 13 : xacmaz
# Processing Record 11 of Set 13 : madimba
# Processing Record 12 of Set 13 : sarangani
# Processing Record 13 of Set 13 : huilong
# Processing Record 14 of Set 13 : sinop
# Processing Record 15 of Set 13 : garoua boulai
# Processing Record 16 of Set 13 : baculin
# Processing Record 17 of Set 13 : la baule-escoublac
# Processing Record 18 of Set 13 : coahuayana
# Processing Record 19 of Set 13 : denholm
# Processing Record 20 of Set 13 : pipri
# Processing Record 21 of Set 13 : jeremoabo
# Processing Record 22 of Set 13 : grand centre
# City not found. Skipping...
# Processing Record 23 of Set 13 : nakatsu
# Processing Record 24 of Set 13 : manadhoo
# Processing Record 25 of Set 13 : assiniboia
# Processing Record 26 of Set 13 : baghdad
# Processing Record 27 of Set 13 : tabou
# Processing Record 28 of Set 13 : warrnambool
# Processing Record 29 of Set 13 : manakara
# Processing Record 30 of Set 13 : saint-georges
# Processing Record 31 of Set 13 : shache
# Processing Record 32 of Set 13 : tateyama
# Processing Record 33 of Set 13 : camacha
# Processing Record 34 of Set 13 : laguna
# Processing Record 35 of Set 13 : alexandria
# Processing Record 36 of Set 13 : burnie
# Processing Record 37 of Set 13 : qaqortoq
# Processing Record 38 of Set 13 : kloulklubed
# Processing Record 39 of Set 13 : santa rosa
# Processing Record 40 of Set 13 : grand gaube
# Processing Record 41 of Set 13 : bilma
# Processing Record 42 of Set 13 : meyungs
# City not found. Skipping...
# Processing Record 43 of Set 13 : tuy hoa
# Processing Record 44 of Set 13 : ostashkov
# Processing Record 45 of Set 13 : zambrow
# Processing Record 46 of Set 13 : marrakesh
# Processing Record 47 of Set 13 : ondjiva
# Processing Record 48 of Set 13 : baykit
# Processing Record 49 of Set 13 : neiba
# Processing Record 50 of Set 13 : olhao
# Processing Record 1 of Set 14 : tripoli
# Processing Record 2 of Set 14 : watertown
# Processing Record 3 of Set 14 : elbasan
# Processing Record 4 of Set 14 : voskresenskoye
# Processing Record 5 of Set 14 : tikrit
# Processing Record 6 of Set 14 : sungaipenuh
# Processing Record 7 of Set 14 : katherine
# Processing Record 8 of Set 14 : derbent
# Processing Record 9 of Set 14 : kostomuksha
# Processing Record 10 of Set 14 : aleksandrov gay
# Processing Record 11 of Set 14 : christchurch
# Processing Record 12 of Set 14 : likasi
# Processing Record 13 of Set 14 : bukavu
# Processing Record 14 of Set 14 : berdigestyakh
# Processing Record 15 of Set 14 : matanzas
# Processing Record 16 of Set 14 : mnogovershinnyy
# Processing Record 17 of Set 14 : flinders
# Processing Record 18 of Set 14 : mafinga
# Processing Record 19 of Set 14 : sibenik
# Processing Record 20 of Set 14 : hobyo
# Processing Record 21 of Set 14 : bonavista
# Processing Record 22 of Set 14 : ambon
# Processing Record 23 of Set 14 : alice springs
# Processing Record 24 of Set 14 : coos bay
# Processing Record 25 of Set 14 : bom jesus
# Processing Record 26 of Set 14 : miles city
# Processing Record 27 of Set 14 : spas-klepiki
# Processing Record 28 of Set 14 : kosh-agach
# Processing Record 29 of Set 14 : pontianak
# Processing Record 30 of Set 14 : katesh
# Processing Record 31 of Set 14 : dawlatabad
# Processing Record 32 of Set 14 : tabas
# Processing Record 33 of Set 14 : stephenville
# Processing Record 34 of Set 14 : mishelevka
# Processing Record 35 of Set 14 : ulladulla
# Processing Record 36 of Set 14 : burns lake
# Processing Record 37 of Set 14 : kanalion
# Processing Record 38 of Set 14 : lomza
# Processing Record 39 of Set 14 : atar
# Processing Record 40 of Set 14 : goderich
# Processing Record 41 of Set 14 : manggar
# Processing Record 42 of Set 14 : arlit
# Processing Record 43 of Set 14 : wahpeton
# Processing Record 44 of Set 14 : nisia floresta
# Processing Record 45 of Set 14 : nampula
# Processing Record 46 of Set 14 : lufilufi
# Processing Record 47 of Set 14 : santa cruz
# Processing Record 48 of Set 14 : morris
# Processing Record 49 of Set 14 : marsaxlokk
# Processing Record 50 of Set 14 : skagastrond
# City not found. Skipping...
# Processing Record 1 of Set 15 : bolivar
# Processing Record 2 of Set 15 : andenes
# Processing Record 3 of Set 15 : salto
# Processing Record 4 of Set 15 : aklavik
# Processing Record 5 of Set 15 : sayville
# Processing Record 6 of Set 15 : visnes
# Processing Record 7 of Set 15 : kanakapura
# Processing Record 8 of Set 15 : tsirguliina
# Processing Record 9 of Set 15 : abrau-dyurso
# Processing Record 10 of Set 15 : colares
# Processing Record 11 of Set 15 : cocorit
# Processing Record 12 of Set 15 : bonanza
# Processing Record 13 of Set 15 : leh
# Processing Record 14 of Set 15 : kilindoni
# Processing Record 15 of Set 15 : preobrazheniye
# Processing Record 16 of Set 15 : tignere
# Processing Record 17 of Set 15 : kodinsk
# Processing Record 18 of Set 15 : nadym
# Processing Record 19 of Set 15 : poopo
# Processing Record 20 of Set 15 : saravena
# Processing Record 21 of Set 15 : roswell
# Processing Record 22 of Set 15 : bam
# Processing Record 23 of Set 15 : tamandare
# Processing Record 24 of Set 15 : forio
# Processing Record 25 of Set 15 : gilazi
# City not found. Skipping...
# Processing Record 26 of Set 15 : behshahr
# Processing Record 27 of Set 15 : mayo
# Processing Record 28 of Set 15 : xianshuigu
# Processing Record 29 of Set 15 : keti bandar
# Processing Record 30 of Set 15 : winton
# Processing Record 31 of Set 15 : montbrison
# Processing Record 32 of Set 15 : san felipe
# Processing Record 33 of Set 15 : libertad
# Processing Record 34 of Set 15 : kieta
# Processing Record 35 of Set 15 : cortez
# Processing Record 36 of Set 15 : sorong
# Processing Record 37 of Set 15 : zhigansk
# Processing Record 38 of Set 15 : beyneu
# Processing Record 39 of Set 15 : kinshasa
# Processing Record 40 of Set 15 : verkhoyansk
# Processing Record 41 of Set 15 : sabang
# Processing Record 42 of Set 15 : tsihombe
# City not found. Skipping...
# Processing Record 43 of Set 15 : puro
# Processing Record 44 of Set 15 : hernani
# Processing Record 45 of Set 15 : utiroa
# City not found. Skipping...
# Processing Record 46 of Set 15 : kununurra
# Processing Record 47 of Set 15 : novyy urgal
# Processing Record 48 of Set 15 : terney
# Processing Record 49 of Set 15 : huanan
# Processing Record 50 of Set 15 : kulhudhuffushi
# Processing Record 1 of Set 16 : marand
# Processing Record 2 of Set 16 : poya
# Processing Record 3 of Set 16 : kayes
# Processing Record 4 of Set 16 : luneville
# Processing Record 5 of Set 16 : karsava
# Processing Record 6 of Set 16 : manuk mangkaw
# Processing Record 7 of Set 16 : naze
# Processing Record 8 of Set 16 : havelock
# Processing Record 9 of Set 16 : srandakan
# Processing Record 10 of Set 16 : pafos
# Processing Record 11 of Set 16 : tabarqah
# City not found. Skipping...
# Processing Record 12 of Set 16 : ovalle
# Processing Record 13 of Set 16 : mahajanga
# Processing Record 14 of Set 16 : havoysund
# Processing Record 15 of Set 16 : gazanjyk
# Processing Record 16 of Set 16 : camana
# Processing Record 17 of Set 16 : vilyuysk
# Processing Record 18 of Set 16 : mizpe ramon
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Make sure we have at least 500 cities.  
if len(city_data) >= 500:
    print("Collected more than 500 cities.")
else:
    print("Generate more lat/lngs pairs.")
# Out:
# Collected more than 500 cities.

# %%
# Deliverable 1, Step 7: Add the data to a new DataFrame.


# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

new_column_order = ["City", "Country", "Date","Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Weather Description"]
city_data_df = city_data_df[new_column_order]

city_data_df.head()
# Out:
#              City Country                 Date    Lat     Lng  Max Temp  \
# 0          Hobart      AU  2020-11-07 18:29:16 -42.88  147.33     42.01
# 1  Saint-Philippe      RE  2020-11-07 18:31:51 -21.36   55.77     73.40
# 2        Thompson      CA  2020-11-07 18:31:51  55.74  -97.86     17.60
# 3           Gorin      RU  2020-11-07 18:31:51  51.20  136.67     19.67
# 4     New Norfolk      AU  2020-11-07 18:31:13 -42.78  147.06     42.01
#
#    Humidity  Cloudiness  Wind Speed Weather Description
# 0        86           0        9.17           clear sky
# 1        78          75       17.22       broken clouds
# 2        85          90        2.24          light snow
# 3        90         100        5.86     overcast clouds
# 4        72           6        2.57           clear sky

# %%
# Deliverable 1, Step 8: Export the DataFrame as a CSV file

# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data DF into a CSV -- with the index as City_ID
city_data_df.to_csv(output_data_file, index_label="City_ID")
